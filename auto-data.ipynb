# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
auto = pd.read_csv("C:/Users/admin/Downloads/auto_data.csv")
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.tail(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
print(list(auto.columns))
# Out:
# ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'name']

# %%
auto.describe(include='all')
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model_year      origin        name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
# display the correlation heatmap of the dataframe
sns.heatmap(auto.corr(),cmap='coolwarm',annot=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8976\2368345095.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(auto.corr(),cmap='coolwarm',annot=True)
# <Axes: >

# %%
# plot a line chart of the mean by Cylinders
auto.groupby('cylinders').mean().plot(kind='line')
plt.title('mean by cylinders')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8976\2888179406.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   auto.groupby('cylinders').mean().plot(kind='line')

# %%
# plot a bar chart of the mean by mpg
auto.groupby('origin').mean().plot(kind='bar')
plt.title('mean by origin')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8976\3899214184.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   auto.groupby('origin').mean().plot(kind='bar')

# %%
# plot a pie chart of the mean by mpg
auto.groupby('origin').mean().plot(kind='box')
plt.title('mean by origin')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8976\978558445.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   auto.groupby('origin').mean().plot(kind='box')

# %%
# create a pair plot of mpg, weight, and origin with hue set to origin
sns.pairplot(auto[['mpg','weight','origin']],hue='origin',height=4)

# %%
# replace the question mark with a numeric value (e.g., 0)
auto['horsepower'] = auto['horsepower'].replace('?', 0)

# convert the horsepower column to integer values
auto['horsepower'] = auto['horsepower'].astype(int)

# %%
# filter the dataframe to include only rows where acceleration > 15 and horsepower < 170
filtered_auto =auto[(auto['acceleration']>15) & (auto['horsepower']<= 170)]
print(filtered_auto)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 15   22.0          6         198.0          95    2833          15.5
# 16   18.0          6         199.0          97    2774          15.5
# 17   21.0          6         200.0          85    2587          16.0
# 19   26.0          4          97.0          46    1835          20.5
# 20   25.0          4         110.0          87    2672          17.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0          90    2950          17.3
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model_year  origin                          name horepower
# 15           70       1               plymouth duster        95
# ...

# %%
# group the dataframe by cylinders and count the number of unique values in each group
auto = auto.groupby('cylinders')
counts = auto.size()
print(counts)
# Out:
# cylinders
# 3      4
# 4    204
# 5      3
# 6     84
# 8    103
# dtype: int64

# %%
# group the dataframe by model_year and count the number of rows in each group
model_year_count= auto.groupby('model_year').size()
print(model_year_count)
# Out:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# dtype: int64
