# %%
import pandas as pd

# %%
emp= pd.read_csv("C:/Users/admin/Downloads/emp12.csv")
emp
# Out:
#     1231            Sheethal  9874512510   6/6/1985    Software developer  \
# 0   1232                Sonu  7458213640   5/5/1995       Software tester
# 1   1233             Sandeep  9550025123   3/6/1990    Software architect
# 2   1234               Manoj  9254762153   1/7/1990   system adminstrator
# 3   1235            Prasanna  9949171267  6/10/1995      software analyst
# 4   1236            Priyanka  7095724262   6/8/1995                tester
# 5   1237          Shravanthi  9584672135   2/9/1995         Cloud analyst
# 6   1238              Yamini  8657215420   2/6/1995            HR Manager
# 7   1239           Chaitanya  9125467283   7/4/1994             Architect
# 8   1240       Leela Krishna  8542136571   2/3/1994       Software Tester
# 9   1241            Mahender  9676521477   4/5/1985             Developer
# 10  1242  Yelishetty Shankar  9959243211   4/6/1979               Manager
# 11  1243              Swapna  9949343211   2/7/1982  Associate consultant
# ...

# %%
emp.head()
# Out:
#    1231  Sheethal  9874512510   6/6/1985   Software developer   25000  \
# 0  1232      Sonu  7458213640   5/5/1995      Software tester   28000
# 1  1233   Sandeep  9550025123   3/6/1990   Software architect  100000
# 2  1234     Manoj  9254762153   1/7/1990  system adminstrator   65000
# 3  1235  Prasanna  9949171267  6/10/1995     software analyst   15000
# 4  1236  Priyanka  7095724262   6/8/1995               tester   20000
#
#         Hyderbad     7   No
# 0       Madhapur   8.0   No
# 1     Gachibowli   7.5   No
# 2    Hitech city   8.0   No
# 3  Jubliee hills  12.0  Yes
# 4  Banjara Hills   9.0   No

# %%
emp.tail()
# Out:
#     1231            Sheethal  9874512510  6/6/1985    Software developer  \
# 9   1241            Mahender  9676521477  4/5/1985             Developer
# 10  1242  Yelishetty Shankar  9959243211  4/6/1979               Manager
# 11  1243              Swapna  9949343211  2/7/1982  Associate consultant
# 12  1244              Nikhil  8019200557  4/8/1994  financial consultant
# 13  1245           Sai Kumar  9885662939  4/9/1986            HR Manager
#
#      25000  Hyderbad     7   No
# 9    60000      ECIL   7.0   No
# 10  100000   LBNagar  13.0  Yes
# 11   23000   LBNagar   8.0   No
# 12   25000   Tarnaka   8.0   No
# 13   30000  Suchitra   9.0   No

# %%
emp.describe(include='all')
# Out:
#              1231 Sheethal    9874512510  6/6/1985 Software developer  \
# count     14.0000       14  1.400000e+01        14                 14
# unique        NaN       14           NaN        14                 13
# top           NaN     Sonu           NaN  5/5/1995         HR Manager
# freq          NaN        1           NaN         1                  2
# mean    1238.5000      NaN  9.050526e+09       NaN                NaN
# std        4.1833      NaN  9.586112e+08       NaN                NaN
# min     1232.0000      NaN  7.095724e+09       NaN                NaN
# 25%     1235.2500      NaN  8.570906e+09       NaN                NaN
# 50%     1238.5000      NaN  9.402394e+09       NaN                NaN
# 75%     1241.7500      NaN  9.833378e+09       NaN                NaN
# max     1245.0000      NaN  9.959243e+09       NaN                NaN
#
#                 25000     Hyderbad          7   No
# count       14.000000           14  14.000000   14
# ...

# %%
emp.columns = ['id', 'names', 'phno', 'date','roles', 'salary', 'city', 'no', 'col']

# %%
print(list[emp.columns])
# Out:
# list[Index(['id', 'names', 'phno', 'date', 'roles', 'salary', 'city', 'no', 'col'], dtype='object')]

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      14 non-null     int64
#  1   names   14 non-null     object
#  2   phno    14 non-null     int64
#  3   date    14 non-null     object
#  4   roles   14 non-null     object
#  5   salary  14 non-null     int64
#  6   city    14 non-null     object
#  7   no      14 non-null     float64
#  8   col     14 non-null     object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.1+ KB

# %%
# iterate over each row in the dataframe
for index, row in emp.iterrows():
    salary = int(row[5])
    print("Total salary for " + row[1] + " is " + str(salary))
    
    DA = salary * 0.25
    print("DA is " + str(DA))
        
    TZ = salary * 0.15
    print("TZ is " + str(TZ))
        
    HRA = salary * 0.25
    print("HRA is " + str(HRA))
        
    CCA = salary * 0.25
    print("CCA is " + str(CCA))
        
    MA = salary * 0.25
    print("MA is " + str(MA))
        
    LIC = salary * 0.25
    print("LIC is " + str(LIC))
        
    net_salary = DA + TZ + HRA + MA + LIC
    print("NET-salary for " + row[1] + " is " + str(net_salary))
    print('\n')
# Out:
# Total salary for Sonu is 28000
# DA is 7000.0
# TZ is 4200.0
# HRA is 7000.0
# CCA is 7000.0
# MA is 7000.0
# LIC is 7000.0
# NET-salary for Sonu is 32200.0
#
#
# Total salary for Sandeep is 100000
# DA is 25000.0
# TZ is 15000.0
# HRA is 25000.0
# CCA is 25000.0
# MA is 25000.0
# LIC is 25000.0
# NET-salary for Sandeep is 115000.0
#
#
# Total salary for Manoj is 65000
# DA is 16250.0
# TZ is 9750.0
# HRA is 16250.0
# CCA is 16250.0
# MA is 16250.0
# LIC is 16250.0
# NET-salary for Manoj is 74750.0
#
#
# Total salary for Prasanna is 15000
# DA is 3750.0
# TZ is 2250.0
# HRA is 3750.0
# CCA is 3750.0
# MA is 3750.0
# LIC is 3750.0
# NET-salary for Prasanna is 17250.0
#
#
# Total salary for Priyanka is 20000
# DA is 5000.0
# TZ is 3000.0
# HRA is 5000.0
# CCA is 5000.0
# MA is 5000.0
# LIC is 5000.0
# NET-salary for Priyanka is 23000.0
#
#
# Total salary for Shravanthi is 28000
# DA is 7000.0
# TZ is 4200.0
# HRA is 7000.0
# CCA is 7000.0
# MA is 7000.0
# LIC is 7000.0
# ...
