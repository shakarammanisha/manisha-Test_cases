# %%
import pandas as pd

# %%
df= pd .read_csv("C:/Users/admin/Downloads/real state.csv")
df
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %%
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
df.tail()
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type                     sale_date   price   latitude   longitude
# 980  Residential  Thu May 15 00:00:00 EDT 2008  232425  38.457679 -121.359620
# 981  Residential  Thu May 15 00:00:00 EDT 2008  234000  38.499893 -121.458890
# 982  Residential  Thu May 15 00:00:00 EDT 2008  235000  38.708824 -121.256803
# 983  Residential  Thu May 15 00:00:00 EDT 2008  235301  38.417000 -121.397424
# 984  Residential  Thu May 15 00:00:00 EDT 2008  235738  38.655245 -121.075915

# %%
print(list[df.columns])
# Out:
# list[Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
df.describe(include='all')
# Out:
#                 street        city           zip state        beds  \
# count              985         985    985.000000   985  985.000000
# unique             981          39           NaN     1         NaN
# top     8306 CURLEW CT  SACRAMENTO           NaN    CA         NaN
# freq                 2         439           NaN   985         NaN
# mean               NaN         NaN  95750.697462   NaN    2.911675
# std                NaN         NaN     85.176072   NaN    1.307932
# min                NaN         NaN  95603.000000   NaN    0.000000
# 25%                NaN         NaN  95660.000000   NaN    2.000000
# 50%                NaN         NaN  95762.000000   NaN    3.000000
# 75%                NaN         NaN  95828.000000   NaN    4.000000
# max                NaN         NaN  95864.000000   NaN    8.000000
#
#              baths       sq__ft         type                     sale_date  \
# count   985.000000   985.000000          985                           985
# ...

# %%
city = df[(df['type'] == 'villa') & (df['price']>=10000)]
# print the resulting dataframe
print(city[['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
       'sale_date', 'price', 'latitude', 'longitude']])
# Out:
#                                   street            city    zip state  beds  \
# 5                     5828 PEPPERMILL CT      SACRAMENTO  95841    CA     3
# 8        11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA  95670    CA     2
# 15                        7340 HAMDEN PL      SACRAMENTO  95842    CA     2
# 17               6236 LONGFORD DR Unit 1  CITRUS HEIGHTS  95621    CA     2
# 30          5201 LAGUNA OAKS DR Unit 140       ELK GROVE  95758    CA     2
# 34          5201 LAGUNA OAKS DR Unit 162       ELK GROVE  95758    CA     2
# 39                      2442 LARKSPUR LN      SACRAMENTO  95825    CA     1
# 40          4800 WESTLAKE PKWY Unit 2109      SACRAMENTO  95835    CA     2
# 94                          4010 ALEX LN      CARMICHAEL  95608    CA     2
# 101              4236 NATOMAS CENTRAL DR      SACRAMENTO  95834    CA     3
# 158              6272 LONGFORD DR Unit 1  CITRUS HEIGHTS  95621    CA     2
# ...

# %%
galt_residential = df[(df['city'] == 'GALT') & (df['type'] == 'Residential') & (df['sq__ft'] > 800)]
print(galt_residential[['street', 'sq__ft', 'sale_date', 'city']])
# Out:
#                   street  sq__ft                     sale_date  city
# 55    1122 WILD POPPY CT    1406  Wed May 21 00:00:00 EDT 2008  GALT
# 61      306 CAMELLIA WAY    1130  Wed May 21 00:00:00 EDT 2008  GALT
# 63            404 6TH ST    1479  Wed May 21 00:00:00 EDT 2008  GALT
# 174   1121 CREEKSIDE WAY    1080  Tue May 20 00:00:00 EDT 2008  GALT
# 189      840 TRANQUIL LN    1266  Tue May 20 00:00:00 EDT 2008  GALT
# 281        993 MANTON CT    2307  Tue May 20 00:00:00 EDT 2008  GALT
# 296    796 BUTTERCUP CIR    2159  Tue May 20 00:00:00 EDT 2008  GALT
# 307      1092 MAUGHAM CT    3746  Tue May 20 00:00:00 EDT 2008  GALT
# 372         201 CARLO CT    1080  Mon May 19 00:00:00 EDT 2008  GALT
# 402  746 MOOSE CREEK WAY    1100  Mon May 19 00:00:00 EDT 2008  GALT
# 409        332 PALIN AVE    1204  Mon May 19 00:00:00 EDT 2008  GALT
# 439        913 COBDEN CT    1555  Mon May 19 00:00:00 EDT 2008  GALT
# 454      709 CIMMARON CT    1798  Mon May 19 00:00:00 EDT 2008  GALT
# ...

# %%
residential = df[(df['type'] == 'Residential') & (df['beds'] > 2)]
print(residential[['city', 'baths', 'sq__ft', 'price', 'type','beds']])
# Out:
#                 city  baths  sq__ft   price         type  beds
# 1         SACRAMENTO      1    1167   68212  Residential     3
# 6         SACRAMENTO      2    1104   90895  Residential     3
# 7         SACRAMENTO      1    1177   91002  Residential     3
# 9          RIO LINDA      2    1146   98937  Residential     3
# 10        SACRAMENTO      2     909  100309  Residential     3
# ..               ...    ...     ...     ...          ...   ...
# 980       SACRAMENTO      3    2280  232425  Residential     4
# 981       SACRAMENTO      2    1477  234000  Residential     3
# 982   CITRUS HEIGHTS      2    1216  235000  Residential     3
# 983        ELK GROVE      2    1685  235301  Residential     4
# 984  EL DORADO HILLS      2    1362  235738  Residential     3
#
# [715 rows x 6 columns]

# %%
reidential = df[(df['price'] > 60000) & (df['price'] < 120000) & (df['sq__ft'] > 1450) & (df['beds'] >=3) & (df['baths'] >=2) 
            & (df['type']=='residential')]
print(residential.head(5))
# Out:
#                  street        city    zip state  beds  baths  sq__ft  \
# 1           51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 6   6048 OGDEN NASH WAY  SACRAMENTO  95842    CA     3      2    1104
# 7         2561 19TH AVE  SACRAMENTO  95820    CA     3      1    1177
# 9          7325 10TH ST   RIO LINDA  95673    CA     3      2    1146
# 10     645 MORRISON AVE  SACRAMENTO  95838    CA     3      2     909
#
#            type                     sale_date   price   latitude   longitude
# 1   Residential  Wed May 21 00:00:00 EDT 2008   68212  38.478902 -121.431028
# 6   Residential  Wed May 21 00:00:00 EDT 2008   90895  38.681659 -121.351705
# 7   Residential  Wed May 21 00:00:00 EDT 2008   91002  38.535092 -121.481367
# 9   Residential  Wed May 21 00:00:00 EDT 2008   98937  38.700909 -121.442979
# 10  Residential  Wed May 21 00:00:00 EDT 2008  100309  38.637663 -121.451520

# %%
# Filter the data
ca_villa = df[(df['state'] == 'CA') & (df['type'] == 'villa')]

# Find the cheapest property
cheapest_property = ca_villa.loc[ca_villa['price'].idxmin()]

# Display the details of the cheapest property
print('The cheapest villa property in California is located at', cheapest_property['street'], ',', cheapest_property['city'], '.', 'It has', cheapest_property['beds'], 'bedrooms,', cheapest_property['baths'], 'bathrooms, and is', cheapest_property['sq__ft'], 'sq__ft in size. The price of this property is $', cheapest_property['price'], '.')
# Out:
# The cheapest villa property in California is located at 5840 WALERGA RD , SACRAMENTO . It has 2 bedrooms, 1 bathrooms, and is 840 sq__ft in size. The price of this property is $ 40000 .
